# %%
# Import required libraries
import pandas as pd
import matplotlib.pyplot as plt
from datasets import load_dataset

# 1. Load the dataset directly from Hugging Face
print("Downloading the dataset...")
dataset = load_dataset("bitext/Bitext-customer-support-llm-chatbot-training-dataset")

# 2. Convert the training split to a Pandas DataFrame for better exploration
df = dataset['train'].to_pandas()

# 3. View the total count and the first few rows
print(f"Total number of tickets: {len(df)}")
display(df.head())

# 4. Visualize the distribution of ticket categories (intents)
plt.figure(figsize=(10,6))
df['intent'].value_counts().head(15).plot(kind='barh', color='skyblue')
plt.title('Top 15 Customer Support Ticket Categories')
plt.gca().invert_yaxis()  # Invert Y-axis to show the highest frequency at the top
plt.show()
# Out:
# ...
# README.md: 0.00B [00:00, ?B/s]
# c:\Users\Martin Barros\OneDrive\Escritorio\UDC\Otros\Proyectos Python\mlops-ticket-classifier\venv\Lib\site-packages\huggingface_hub\file_download.py:138: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\Martin Barros\.cache\huggingface\hub\datasets--bitext--Bitext-customer-support-llm-chatbot-training-dataset. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# ...
